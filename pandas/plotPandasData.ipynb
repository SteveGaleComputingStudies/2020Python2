# %%
#https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/04_plotting.html
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv("C:/Users/sgale/OneDrive/2020-Teaching/Python ADCSE2/code/pandas/data/air_quality_no2.csv", index_col=0, parse_dates=True )

# %%
air_quality.head(6)
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# 2019-05-07 07:00:00              NaN           72.4            26.0

# %%
air_quality.plot()

# %%
air_quality["station_paris"].plot()
