# %%
import pandas as pd

# %%
occupancy = pd.read_csv("occupancy.csv")

# %%
occupancy
# Out:
#         id              date  Temperature   Humidity       Light          CO2  \
# 0        1  11/02/2015 14:48    21.760000  31.133333  437.333333  1029.666667
# 1        2  11/02/2015 14:49    21.790000  31.000000  437.333333  1000.000000
# 2        3  11/02/2015 14:50    21.767500  31.122500  434.000000  1003.750000
# 3        4  11/02/2015 14:51    21.767500  31.122500  439.000000  1009.500000
# 4        5  11/02/2015 14:51    21.790000  31.133333  437.333333  1005.666667
# 5        6  11/02/2015 14:53    21.760000  31.260000  437.333333  1014.333333
# 6        7  11/02/2015 14:54    21.790000  31.197500  434.000000  1018.500000
# 7        8  11/02/2015 14:55    21.790000  31.393333  437.333333  1018.666667
# 8        9  11/02/2015 14:55    21.790000  31.317500  434.000000  1022.000000
# 9       10  11/02/2015 14:57    21.790000  31.463333  437.333333  1027.333333
# 10      11  11/02/2015 14:57    21.790000  31.525000  437.750000  1047.750000
# ...

# %%
#I want to see the first 8 rows of a pandas DataFrame.
occupancy.head(8)
# Out:
#    id              date  Temperature   Humidity       Light          CO2  \
# 0   1  11/02/2015 14:48      21.7600  31.133333  437.333333  1029.666667
# 1   2  11/02/2015 14:49      21.7900  31.000000  437.333333  1000.000000
# 2   3  11/02/2015 14:50      21.7675  31.122500  434.000000  1003.750000
#
#    HumidityRatio  Occupancy
# 0       0.005021          1
# 1       0.005009          1
# 2       0.005022          1

# %%
#I want to see the last 8 rows of a pandas DataFrame.
occupancy.tail(8)
# Out:
#         id             date  Temperature   Humidity   Light      CO2  \
# 9744  9745  18/02/2015 9:11       20.790  27.030000  419.00  1488.00
# 9745  9746  18/02/2015 9:13       20.790  27.296667  429.00  1486.00
# 9746  9747  18/02/2015 9:14       20.815  27.417500  430.75  1511.75
# 9747  9748  18/02/2015 9:15       20.815  27.717500  429.75  1505.25
# 9748  9749  18/02/2015 9:16       20.865  27.745000  423.50  1514.50
# 9749  9750  18/02/2015 9:16       20.890  27.745000  423.50  1521.50
# 9750  9751  18/02/2015 9:17       20.890  28.022500  418.75  1632.00
# 9751  9752  18/02/2015 9:19       21.000  28.100000  409.00  1864.00
#
#       HumidityRatio  Occupancy
# 9744       0.004101          1
# 9745       0.004142          1
# 9746       0.004167          1
# 9747       0.004213          1
# 9748       0.004230          1
# 9749       0.004237          1
# 9750       0.004279          1
# 9751       0.004321          1

# %%
# Datatypes
occupancy.dtypes
# Out:
# id                 int64
# date              object
# Temperature      float64
# Humidity         float64
# Light            float64
# CO2              float64
# HumidityRatio    float64
# Occupancy          int64
# dtype: object

# %%
#write data to excel
occupancy.to_excel('occupancy.xlsx', sheet_name='room data', index=False)

# %%
occupancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9752 entries, 0 to 9751
# Data columns (total 8 columns):
# id               9752 non-null int64
# date             9752 non-null object
# Temperature      9752 non-null float64
# Humidity         9752 non-null float64
# Light            9752 non-null float64
# CO2              9752 non-null float64
# HumidityRatio    9752 non-null float64
# Occupancy        9752 non-null int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 609.6+ KB
